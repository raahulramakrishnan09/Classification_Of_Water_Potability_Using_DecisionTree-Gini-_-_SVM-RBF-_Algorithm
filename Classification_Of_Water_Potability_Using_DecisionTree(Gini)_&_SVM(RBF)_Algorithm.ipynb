# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/water_potability.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
#Filling_the_missing_values_using_fillna
df['ph']=df['ph'].fillna(df['ph'].mean())
df['Sulfate']=df['Sulfate'].fillna(df['Sulfate'].mean())
df['Trihalomethanes']=df['Trihalomethanes'].fillna(df['Trihalomethanes'].mean())
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
a=df['Trihalomethanes']
plt.plot(a)

# %%
b=df['ph']
plt.scatter(a,b)

# %%
plt.bar(a,height=30,width=10)
# Out:
# <BarContainer object of 3276 artists>

# %%
plt.hist(a)
# Out:
# (array([   3.,   23.,  103.,  347.,  746., 1111.,  655.,  223.,   55.,
#           10.]),
#  array([  0.738 ,  13.0642,  25.3904,  37.7166,  50.0428,  62.369 ,
#          74.6952,  87.0214,  99.3476, 111.6738, 124.    ]),
#  <BarContainer object of 10 artists>)

# %%
sns.lineplot(x=a,y=b,data=df)
# Out:
# <Axes: xlabel='Trihalomethanes', ylabel='ph'>

# %%
sns.scatterplot(x=a,y=b,data=df)
# Out:
# <Axes: xlabel='Trihalomethanes', ylabel='ph'>

# %%
#finding_outliers_using_for_loop
plt.figure(figsize=(20,15))
plotnumber=1

for col in df.columns:
  if plotnumber<=9:
    plt.subplot(5,5,plotnumber)
    sns.boxplot(df[col])
    plt.xlabel(col,fontsize=15)

  plotnumber +=1
plt.tight_layout()
plt.show()

# %%
df=df.drop('Sulfate',axis=1)

# %%
y=df['Potability']
x=df.drop('Potability',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
a=StandardScaler()
x_train=a.fit_transform(x_train)
x_train
# Out:
# array([[-1.07086671e+00,  9.72490169e-01,  1.53580712e+00, ...,
#          1.88037902e-01, -1.25125089e+00, -1.51463513e+00],
#        [ 6.22690117e-05,  4.21409725e-01, -9.44335143e-01, ...,
#         -1.18739347e+00, -1.34485656e+00, -7.84376101e-01],
#        [ 6.22690117e-05,  1.12930924e+00, -1.16949260e+00, ...,
#          1.21207458e+00, -1.51137132e+00, -5.97391587e-01],
#        ...,
#        [-2.95897187e-01, -1.56852166e-01, -7.72119075e-01, ...,
#          3.40476948e-01, -6.33011364e-01, -1.85342018e-01],
#        [ 4.07029896e-01,  1.11222141e+00,  2.00245762e-01, ...,
#          1.24828798e+00, -3.50184633e-01,  1.37466739e+00],
#        [ 6.22690117e-05, -1.10350772e+00, -9.13227361e-01, ...,
#          2.71486171e-01,  5.74235967e-01,  2.16385356e-01]])

# %%
from sklearn.svm import SVC
clf= SVC(kernel="rbf")

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.6280487804878049

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[412, 244],
#        [  0,   0]])

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier(criterion='gini')

# %%
clf1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1=clf1.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.6280487804878049
